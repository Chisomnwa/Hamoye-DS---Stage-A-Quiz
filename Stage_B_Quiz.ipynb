# %% [markdown]
#  **1.** Which people know the theory and the product inside and out?
#
# **Options**
#
# A. Technicians
#
# B. Non specialists
#
# C. Experts
#
# D. Executives
#
# **ANS** - C
#
#
#
#  **2**. Which one is not related to the writing process?
#
# **Options**
#
# A. Topic ideas
#
# B. Drawing
#
# C. Outlining
#
# D. Invention
#
# **ANS** - D
#
#
#
#  **3**. To write in a task-oriented manner, you first have to do some
#
# **Options**
#
# A. Brainstorming
#
# B. Proof
#
# C. Task analysis
#
# D. Planning
#
# **ANS** - A
#
#
#
#  **4**. A technical report should never based on
#
# **Options**
#
# A. Personal prejudices
#
# B. Test
#
# C. Facts
#
# D. Experiments
#
# **ANS** - A
#
#
#
# **5**. Which of the commands below is used to view the distribution of data in pandas?
#
# **Options**
#
# A. distribute()
#
# B. head()
#
# C. sample()
#
# D. describe()
#
# **ANS** - D
#
#
#
#  **6**. Which of the seaborn graphics is used to show all the correlations between variables in a dataset?
#
# **Options**
#
# A. Jointplot
#
# B. Scatterplot
#
# C. heatmap
#
# D. Relplot
#
# **ANS** - C
#
#
#
#  **7**. The following are the several possible ways to work with Power BI except;
#
# **Options**
#
# A. Desktop App
#
# B. PowerBI report
#
# C. Embedded
#
# D. Power BI Web
#
# **ANS** - B
#
#
#
# **8**. Which of the Python libraries is best for drawing maps?
#
# **Options**
#
# A. Matplotlib
#
# B. Folium
#
# C. seaborn
#
# D. Scikit learn
#
# **ANS** - B
#
#
#
#  **9**. To initialize the style of the graphics of seaborn, we use the ------ command
#
# **Options**
#
# A. sns.plot()
#
# B. sns.init()
#
# C. sns.show()
#
# D. sns.set()
#
# **ANS** - D
#
#
#
# **10**. --------- is used to generate a sample random row or column from the function caller data frame.
#
# **Options**
#
# A. info()
#
# B. head()
#
# C. None of the above
#
# D. sample()
#
# **ANS** - D
