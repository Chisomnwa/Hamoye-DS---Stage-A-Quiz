# %% [markdown]
# ## Food Balance Sheet Analysis

# %% [markdown]
# ## Dataset Overview
#
# This food Balance Sheet compiled by the Food and Agriculture Organization of the United Nations contains selection of African countries food country supply between 2014 to 2018.
#
# This food balance sheet shows the food items for human consumption, along with how much was produced, used, imported/exported, and how it benefits the society (per capita supply).
#
#
# ### The dataset is provided by the Food and Agriculture Organization of the United Nations

# %% [markdown]
# ### Questions for Analysis
#
# **Global food and feed production comparison:**
#
#  1. Analysis of changes in production in the years available
#
#  2. Which countries were the largest producers?
#
#  3. Which foods and feedingstuffs were the most commonly produced?

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# import dataset to pandas dataframe
df_FBS = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='Latin-1')

print(df_FBS.shape)

df_FBS.head(15)
# Out:
# (60943, 12)
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# 12          4  Algeria       2905  Cereals - Excluding Beer          5611
# 13          4  Algeria       2905  Cereals - Excluding Beer          5072
# 14          4  Algeria       2905  Cereals - Excluding Beer          5911
#
#                                    Element             Unit     Y2014  \
# 0            Total Population - Both sexes     1000 persons  38924.00
# 1                 Domestic supply quantity      1000 tonnes      0.00
# 2            Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3   Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4       Fat supply quantity (g/capita/day)     g/capita/day     80.06
# 5            Food supply (kcal/capita/day)  kcal/capita/day   2932.00
# 6   Protein supply quantity (g/capita/day)     g/capita/day     67.14
# 7       Fat supply quantity (g/capita/day)     g/capita/day     53.84
# 8            Food supply (kcal/capita/day)  kcal/capita/day    444.00
# 9   Protein supply quantity (g/capita/day)     g/capita/day     27.76
# 10      Fat supply quantity (g/capita/day)     g/capita/day     26.22
# 11                              Production      1000 tonnes   3436.00
# 12                         Import Quantity      1000 tonnes  12604.00
# 13                         Stock Variation      1000 tonnes    684.00
# 14                         Export Quantity      1000 tonnes      3.00
#
#        Y2015     Y2016     Y2017     Y2018
# 0   39728.00  40551.00  41389.00  42228.00
# 1       0.00      0.00      0.00      0.00
# 2    3379.00   3372.00   3341.00   3322.00
# 3      94.35     94.72     92.82     91.83
# 4      79.36     77.40     80.19     77.28
# 5    2958.00   2941.00   2921.00   2932.00
# 6      67.38     67.37     66.11     67.10
# 7      54.72     52.04     55.59     54.57
# 8     421.00    431.00    421.00    390.00
# 9      26.97     27.35     26.71     24.73
# 10     24.64     25.37     24.60     22.71
# 11   3761.00   3445.00   3478.00   6065.00
# 12  13983.00  13523.00  13039.00  13182.00
# 13   1663.00    905.00    705.00   2226.00
# 14      7.00      7.00     10.00     17.00

# %%
# make a copy of the dataframe before data cleaning
food_Balance_Sheet = df_FBS.copy()

food_Balance_Sheet.head() # just to confirm if we have a copy of the dataframe
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# 3     94.35     94.72     92.82     91.83
# 4     79.36     77.40     80.19     77.28

# %%
# Delete unnecessary columns
food_Balance_Sheet.drop(columns=['Area Code', 'Item Code', 'Element Code'], inplace = True)

# %%
# Remove 'Y' from the year's labels
food_Balance_Sheet.rename(columns={x:x[1:] for x in food_Balance_Sheet.columns if 'Y' in x}, inplace = True)

# Change the names of some labels
food_Balance_Sheet.rename(columns={'Area': 'country_name', 'Element': 'element', 'Unit': 'unit'}, inplace = True)

# Change all column names to lower case
food_Balance_Sheet.rename(columns = {x:x.lower for x in food_Balance_Sheet.columns}, inplace = True)

# %%
# confirm if our cleaning task worked
food_Balance_Sheet.head()
# Out:
#   <built-in method lower of str object at 0x000002694DD6BF70>  \
# 0                                            Algeria
# 1                                            Algeria
# 2                                            Algeria
# 3                                            Algeria
# 4                                            Algeria
#
#   <built-in method lower of str object at 0x000002694DACBB70>  \
# 0                                         Population
# 1                                         Population
# 2                                        Grand Total
# 3                                        Grand Total
# 4                                        Grand Total
#
#   <built-in method lower of str object at 0x000002694410AC30>  \
# 0                      Total Population - Both sexes
# 1                           Domestic supply quantity
# 2                      Food supply (kcal/capita/day)
# 3             Protein supply quantity (g/capita/day)
# 4                 Fat supply quantity (g/capita/day)
#
#   <built-in method lower of str object at 0x0000026947C59570>  \
# 0                                       1000 persons
# 1                                        1000 tonnes
# 2                                    kcal/capita/day
# 3                                       g/capita/day
# 4                                       g/capita/day
#
#    <built-in method lower of str object at 0x000002694DD7DC70>  \
# 0                                           38924.00
# 1                                               0.00
# 2                                            3377.00
# 3                                              94.90
# 4                                              80.06
#
#    <built-in method lower of str object at 0x000002694DD7D630>  \
# 0                                           39728.00
# 1                                               0.00
# 2                                            3379.00
# 3                                              94.35
# 4                                              79.36
#
#    <built-in method lower of str object at 0x000002694DD7D5B0>  \
# 0                                           40551.00
# 1                                               0.00
# 2                                            3372.00
# 3                                              94.72
# 4                                              77.40
#
#    <built-in method lower of str object at 0x000002694DD7D7B0>  \
# 0                                           41389.00
# 1                                               0.00
# 2                                            3341.00
# 3                                              92.82
# 4                                              80.19
#
#    <built-in method lower of str object at 0x000002694DD7DCF0>
# 0                                           42228.00
# 1                                               0.00
# 2                                            3322.00
# 3                                              91.83
# 4                                              77.28

# %%
food_Balance_Sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 9 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   <built-in method lower of str object at 0x000002694DD6BF70>  60943 non-null  object
#  1   <built-in method lower of str object at 0x000002694DACBB70>  60943 non-null  object
#  2   <built-in method lower of str object at 0x000002694410AC30>  60943 non-null  object
#  3   <built-in method lower of str object at 0x0000026947C59570>  60943 non-null  object
#  4   <built-in method lower of str object at 0x000002694DD7DC70>  59354 non-null  float64
#  5   <built-in method lower of str object at 0x000002694DD7D630>  59395 non-null  float64
#  6   <built-in method lower of str object at 0x000002694DD7D5B0>  59408 non-null  float64
#  7   <built-in method lower of str object at 0x000002694DD7D7B0>  59437 non-null  float64
#  8   <built-in method lower of str object at 0x000002694DD7DCF0>  59507 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 4.2+ MB

# %%
food_Balance_Sheet.describe()
# Out:
#        <built-in method lower of str object at 0x000002694DD7DC70>  \
# count                                       59354.000000
# mean                                          134.196282
# std                                          1567.663696
# min                                         -1796.000000
# 25%                                             0.000000
# 50%                                             0.090000
# 75%                                             8.340000
# max                                        176405.000000
#
#        <built-in method lower of str object at 0x000002694DD7D630>  \
# count                                       59395.000000
# mean                                          135.235966
# std                                          1603.403984
# min                                         -3161.000000
# 25%                                             0.000000
# 50%                                             0.080000
# 75%                                             8.460000
# max                                        181137.000000
#
#        <built-in method lower of str object at 0x000002694DD7D5B0>  \
# count                                       59408.000000
# mean                                          136.555222
# std                                          1640.007194
# min                                         -3225.000000
# 25%                                             0.000000
# 50%                                             0.080000
# 75%                                             8.430000
# max                                        185960.000000
#
#        <built-in method lower of str object at 0x000002694DD7D7B0>  \
# count                                       59437.000000
# mean                                          140.917765
# std                                          1671.862359
# min                                         -1582.000000
# 25%                                             0.000000
# 50%                                             0.100000
# 75%                                             9.000000
# max                                        190873.000000
#
#        <built-in method lower of str object at 0x000002694DD7DCF0>
# count                                       59507.000000
# mean                                          143.758381
# std                                          1710.782658
# min                                         -3396.000000
# 25%                                             0.000000
# 50%                                             0.070000
# 75%                                             9.000000
# max                                        195875.000000

# %%
food_Balance_Sheet.isnull().sum()
# Out:
# <built-in method lower of str object at 0x000002694DD6BF70>       0
# <built-in method lower of str object at 0x000002694DACBB70>       0
# <built-in method lower of str object at 0x000002694410AC30>       0
# <built-in method lower of str object at 0x0000026947C59570>       0
# <built-in method lower of str object at 0x000002694DD7DC70>    1589
# <built-in method lower of str object at 0x000002694DD7D630>    1548
# <built-in method lower of str object at 0x000002694DD7D5B0>    1535
# <built-in method lower of str object at 0x000002694DD7D7B0>    1506
# <built-in method lower of str object at 0x000002694DD7DCF0>    1436
# dtype: int64

# %%
food_Balance_Sheet.duplicated().any()
# Out:
# True

# %%
food_Balance_Sheet['country_name'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 food_Balance_Sheet['country_name'].unique()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'country_name'

# %%
food_Balance_Sheet['item'].unique()

# %%
food_Balance_Sheet['element'].unique()
